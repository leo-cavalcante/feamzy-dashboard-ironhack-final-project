# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing databases

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Users

# %%
users = pd.read_csv("data/exportUser-Grid view.csv")
print(users.shape)
users.head()
# Out:
# (2928, 12)
#                          id                          username  \
# 0  6005952dcecc894bde4dbe4b  2d76471e6f56a63e6f0105dd92db4254
# 1  5e47f02c09468c00014ebdd9  2d76471e6f56a63e6f0105dd92db4254
# 2  5ed171d3bc261f00011dcb3c  2d76471e6f56a63e6f0105dd92db4254
# 3  5ed505fd719a5e000135831c  2d76471e6f56a63e6f0105dd92db4254
# 4  5f0e0c946cae5e0001128704  2d76471e6f56a63e6f0105dd92db4254
#
#                           firstName                          lastName  \
# 0  d42c0e46682ec1a404afae4d5cc380e1  e8b55f64846685a7d1b1cf2e6ec63ce4
# 1  d42c0e46682ec1a404afae4d5cc380e1  e8b55f64846685a7d1b1cf2e6ec63ce4
# 2  d42c0e46682ec1a404afae4d5cc380e1  e8b55f64846685a7d1b1cf2e6ec63ce4
# 3  d42c0e46682ec1a404afae4d5cc380e1  e8b55f64846685a7d1b1cf2e6ec63ce4
# 4  d42c0e46682ec1a404afae4d5cc380e1  e8b55f64846685a7d1b1cf2e6ec63ce4
#
#    nbPhoneNumbers  nbEmails city  groupChildSize  groupPersoSize  \
# 0               0         1  NaN               0               0
# ...

# %%
users.groupChildSize.value_counts(dropna=False)
# Out:
# 0    2354
# 1     438
# 2      99
# 3      26
# 4       7
# 5       4
# Name: groupChildSize, dtype: int64

# %%
users.city.value_counts(dropna=False)
# Out:
# NaN            2924
# Puteaux           1
# chatenay          1
# panam             1
# La Saussaye       1
# Name: city, dtype: int64

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2928 entries, 0 to 2927
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2928 non-null   object
#  1   username              2928 non-null   object
#  2   firstName             2928 non-null   object
#  3   lastName              2928 non-null   object
#  4   nbPhoneNumbers        2928 non-null   int64
#  5   nbEmails              2928 non-null   int64
#  6   city                  4 non-null      object
#  7   groupChildSize        2928 non-null   int64
#  8   groupPersoSize        2928 non-null   int64
#  9   creationDate          2928 non-null   object
#  10  lastModificationDate  2928 non-null   object
#  11  mapAttributs          0 non-null      float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 274.6+ KB

# %%
users.isna().sum()
# Out:
# id                         0
# username                   0
# firstName                  0
# lastName                   0
# nbPhoneNumbers             0
# nbEmails                   0
# city                    2924
# groupChildSize             0
# groupPersoSize             0
# creationDate               0
# lastModificationDate       0
# mapAttributs            2928
# dtype: int64

# %%
users.city.unique()
# Out:
# array([nan, 'panam', 'La Saussaye', 'chatenay', 'Puteaux'], dtype=object)

# %%
users.nbPhoneNumbers.unique()
# Out:
# array([0, 1])

# %% [markdown]
# ## Class data

# %%
class_data = pd.read_csv("data/exportClassStats-Grid 2020-2021.csv")
print(class_data.shape)
class_data.head()
# Out:
# (313, 28)
#                          id           level                 name schoolYear  \
# 0  5f49130c4ded6f0001f02861            5ème                   S5  2020-2021
# 1  5f4917204ded6f0001f030c0  Petite section                   s5  2020-2021
# 2  5f4912c94ded6f0001f027f2  Grande section                   T1  2020-2021
# 3  5f49139a4ded6f0001f02a08  Petite section  Classe Madame Sarah  2020-2021
# 4  5f4906584ded6f0001f02685  Petite section       non scolarisés  2020-2021
#
#        creationDate  status  nbChild  schoolid secteur_public_prive_libe  \
# 0  2020-08-28 16:22     NaN      1.0       NaN                    Public
# 1  2020-08-28 16:39     NaN      0.0       NaN                    Public
# 2  2020-08-28 16:20     NaN      2.0       NaN                    Public
# 3  2020-08-28 16:24     NaN      3.0       NaN                    Public
# 4  2020-08-28 15:27     NaN      2.0       NaN                    Public
#
# ...

# %%
class_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         313 non-null    object
#  1   level                      313 non-null    object
#  2   name                       313 non-null    object
#  3   schoolYear                 313 non-null    object
#  4   creationDate               313 non-null    object
#  5   status                     0 non-null      float64
#  6   nbChild                    313 non-null    float64
#  7   schoolid                   0 non-null      float64
#  8   secteur_public_prive_libe  313 non-null    object
#  9   appellation_officielle     313 non-null    object
#  10  code_postal_uai            313 non-null    int64
#  11  code_commune               313 non-null    object
#  12  libelle_commune            313 non-null    object
# ...

# %%
(class_data.isna().sum()/class_data.shape[0]).round(2)
# Out:
# id                           0.00
# level                        0.00
# name                         0.00
# schoolYear                   0.00
# creationDate                 0.00
# status                       1.00
# nbChild                      0.00
# schoolid                     1.00
# secteur_public_prive_libe    0.00
# appellation_officielle       0.00
# code_postal_uai              0.00
# code_commune                 0.00
# libelle_commune              0.00
# localite_acheminement_uai    0.00
# libelle_departement          0.00
# libelle_region               0.00
# geometry_type                0.01
# coordinatesLat               0.01
# coordinatesLong              0.01
# exportHomeworkRequest        1.00
# lastModificationDate         0.00
# Table 8                      1.00
# exportHomeworkRequest 2      1.00
# exportHomeworkRequest 3      1.00
# coordinates                  0.00
# nbArchivedChildren           0.00
# cacheMap                     0.00
# ...

# %% [markdown]
# ## Events

# %%
events = pd.read_csv("data/exportEvent-Grid view.csv")
print(events.shape)
events.head()
# Out:
# (2426, 22)
#                          id                      label  \
# 0  5e6093839fed0e000155fef3  Lancement programmé Start
# 1  5e61123e9fed0e00015600a6         Dîner dailyartfair
# 2  5e75d5179fed0e000191fcec     Un petit télé apéro ?
# 3  5ec28f8b7b059100010baa8f        Côte de boeuf party
# 4  5e62410b9fed0e000156035a                 Mix Mondes
#
#                              description                       location  \
# 0                        Lancement + dej  Willa 35 rue du Sentier Paris
# 1                                    NaN                            NaN
# 2                                    NaN                       En visio
# 3  La côte de bœuf, c'est bon. Miam miam                    La Saussaye
# 4               Atelier pour les enfants               La Gaité lyrique
#
#    nbPeriods firstPeriods-startDate firstPeriods-endDate  \
# 0          1       2020-03-11 11:00     2020-03-11 13:30
# 1          1       2020-03-06 21:51     2020-03-06 23:51
# ...

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2426 entries, 0 to 2425
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           2426 non-null   object
#  1   label                        2412 non-null   object
#  2   description                  862 non-null    object
#  3   location                     1044 non-null   object
#  4   nbPeriods                    2426 non-null   int64
#  5   firstPeriods-startDate       2420 non-null   object
#  6   firstPeriods-endDate         2420 non-null   object
#  7   firstPeriods-nbParticipants  0 non-null      float64
#  8   firstPeriods-status          0 non-null      float64
#  9   firstPeriods-allDay          0 non-null      float64
#  10  author                       2426 non-null   object
#  11  creationDate                 2426 non-null   object
#  12  lastModificationDate         2426 non-null   object
# ...

# %%
(events.isna().sum()/events.shape[0]).round(2)
# Out:
# id                             0.00
# label                          0.01
# description                    0.64
# location                       0.57
# nbPeriods                      0.00
# firstPeriods-startDate         0.00
# firstPeriods-endDate           0.00
# firstPeriods-nbParticipants    1.00
# firstPeriods-status            1.00
# firstPeriods-allDay            1.00
# author                         0.00
# creationDate                   0.00
# lastModificationDate           0.00
# visibility                     0.14
# status                         0.00
# frequencyType                  0.00
# dayOfWeek                      0.00
# dayOfMonth                     0.00
# frequencyValue                 0.00
# groupPartSize                  0.00
# groupOrgSize                   0.00
# eventType                      0.54
# dtype: float64

# %%
events["label"].nunique()/events.shape[0]
# Out:
# 0.281121187139324

# %%
print(events["label"].unique())
# Out:
# ['Lancement programmé Start' 'Dîner dailyartfair' 'Un petit télé apéro ? '
#  'Côte de boeuf party' 'Mix Mondes' 'test' 'le 1' 'le 2'
#  'piscine les vendredi' 'Pot de départ Budget Box Simon' 'soiree apero'
#  'Dîner en Amoureux' 'Semaine de travail au vert' 'Test prod'
#  '1 er test caro' 'un evenement recurent' 'Les lyonnais à Paris'
#  'Truffes, whisky et cigares' 'Test' 'Lancement de la session Bêta test 2'
#  'Dîner marie' 'Test envoi mail' "c'est le week-end !" 'Test Alex'
#  'Test rendez vous ' 'Surf' 'Test event' 'Point' 'Pique-nique'
#  'anniv annelolo' 'Point digital marketing' 'Test date' 'Marché '
#  'Trip à Paris' 'Pendaison de crémaillère' 'Bienvenue à CC'
#  'BBQ de rentrée !' 'Déjeuner Séverine-Alex' 'Déjeuner Delphine-Alex'
#  'Ça progresse ? ' 'Essai' 'Test mail' 'Dîner entre amis ' 'Coucou '
#  'Déjeuner à Paris' "Les parisiens à L'isle-Adam" 'Dîner Danette '
#  "A l'abri de la chaleur" 'Dej fin de vacances ' 'Test feamzy'
# ...

# %%
print(events.frequencyValue.nunique())
print(events.frequencyValue.unique())
# Out:
# 2
# ['1' 'Null']

# %%
print(events.nbPeriods.nunique())
print(events.nbPeriods.unique())
# Out:
# 8
# [ 1  3  2  0  4  5 10  6]

# %% [markdown]
# ## Documents

# %%
documents = pd.read_csv("data/exportDocument-Grid view.csv")
print(documents.shape)
documents.head()
# Out:
# (51, 13)
#                          id               referenceId referenceType userId  \
# 0  5f5c8d759a49ce0001c51e0c  5f4e61b8c154d5000100b02a         CLASS   Null
# 1  5f5c80c6217d3600011d35bc  5f4e61b8c154d5000100b02a         CLASS   Null
# 2  5f5c806e217d3600011d35a9  5f4e61b8c154d5000100b02a         CLASS   Null
# 3  5f5c809e217d3600011d35ae  5f4e61b8c154d5000100b02a         CLASS   Null
# 4  5f5c8056217d3600011d35a5  5f4e61b8c154d5000100b02a         CLASS   Null
#
#         label      description           type              creationDate  \
# 0  Grammaire   desc Grammaire        HOMEWORK  2020-09-12T08:57:25.677Z
# 1         NaN              NaN  HOMEWORK_LIST  2020-09-12T08:03:18.005Z
# 2         NaN              NaN  HOMEWORK_LIST  2020-09-12T08:01:50.911Z
# 3         NaN              NaN  HOMEWORK_LIST  2020-09-12T08:02:38.458Z
# 4         NaN              NaN  HOMEWORK_LIST  2020-09-12T08:01:26.221Z
#
# ...

# %%
documents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    51 non-null     object
#  1   referenceId           51 non-null     object
#  2   referenceType         51 non-null     object
#  3   userId                51 non-null     object
#  4   label                 21 non-null     object
#  5   description           5 non-null      object
#  6   type                  51 non-null     object
#  7   creationDate          51 non-null     object
#  8   lastModificationDate  51 non-null     object
#  9   echueDate             51 non-null     object
#  10  contentType           0 non-null      float64
#  11  authorName            6 non-null      object
#  12  modifier              51 non-null     object
# dtypes: float64(1), object(12)
# memory usage: 5.3+ KB

# %%
(documents.isna().sum()/documents.shape[0]).round(2)
# Out:
# id                      0.00
# referenceId             0.00
# referenceType           0.00
# userId                  0.00
# label                   0.59
# description             0.90
# type                    0.00
# creationDate            0.00
# lastModificationDate    0.00
# echueDate               0.00
# contentType             1.00
# authorName              0.88
# modifier                0.00
# dtype: float64

# %%
documents
# Out:
#                           id               referenceId referenceType  \
# 0   5f5c8d759a49ce0001c51e0c  5f4e61b8c154d5000100b02a         CLASS
# 1   5f5c80c6217d3600011d35bc  5f4e61b8c154d5000100b02a         CLASS
# 2   5f5c806e217d3600011d35a9  5f4e61b8c154d5000100b02a         CLASS
# 3   5f5c809e217d3600011d35ae  5f4e61b8c154d5000100b02a         CLASS
# 4   5f5c8056217d3600011d35a5  5f4e61b8c154d5000100b02a         CLASS
# 5   5f6a0ab5fb6eb600010f6ccd  5f6a0a44046ca50001ad3afe         CLASS
# 6   5f6c9f8d046ca50001ad3e8f  5f4e27ab2447780001556cf0         CLASS
# 7   5f7d7b1f08a33300018cce0a  5f54ce6585b2260001876b6f         CLASS
# 8   5f7deff008a33300018cd0e4  5f7def419fe5530001fd2151         CLASS
# 9   5f64c4ca8001bd00012c95e4  5f4e27ab2447780001556cf0         CLASS
# 10  5f68c1a0046ca50001ad371b  5f4e27ab2447780001556cf0         CLASS
# 11  5f68c1d9046ca50001ad372b  5f4e27ab2447780001556cf0         CLASS
# 12  5f68dbd1fb6eb600010f696e  5f54ce6585b2260001876b6f         CLASS
# ...

# %%
documents.authorName[documents.authorName.notnull()]
# Out:
# 45      GARCIN
# 46    Hounaida
# 47      GARCIN
# 48      Maëlle
# 49       Gault
# 50      myriam
# Name: authorName, dtype: object

# %% [markdown]
# ## Homework

# %%
homework = pd.read_csv("data/exportHomeworkRequest-Grid view.csv")
print(homework.shape)
homework.head()
# Out:
# (567, 11)
#                          id                   classId  \
# 0  5f4914744ded6f0001f02c9e  5f4914554ded6f0001f02c8c
# 1  5f4914b64ded6f0001f02ce9  5f49139a4ded6f0001f02a08
# 2  5f4915a24ded6f0001f02e3d  5f4914934ded6f0001f02cb4
# 3  5f72076dfb6eb600013dda15  5f4e27ab2447780001556cf0
# 4  5f665d52046ca50001ad3403  5f665d10046ca50001ad33f2
#
#                      userId  \
# 0  5f4910754ded6f0001f026a7
# 1  5ec23afd7b059100010baa8b
# 2  5f4911ef4ded6f0001f0271d
# 3  5e5ccf59026b4800016b27b0
# 4  5f665c26fb6eb600010f65eb
#
#                                                label              date  \
# 0   homework list for the day of lundi 31 août, 2020  2020-08-31 00:00
# 1  Liste de devoirs pour la journée du samedi 29 ...  2020-08-29 00:00
# 2  Liste de devoirs pour la journée du samedi 29 ...  2020-08-29 00:00
# 3                                                NaN  2020-09-29 00:00
# 4                                        Les devoirs  2020-09-22 00:00
#
# ...

# %%
homework.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    567 non-null    object
#  1   classId               567 non-null    object
#  2   userId                567 non-null    object
#  3   label                 565 non-null    object
#  4   date                  567 non-null    object
#  5   type                  567 non-null    object
#  6   nbRequestUsers        567 non-null    int64
#  7   creationDate          567 non-null    object
#  8   lastModificationDate  567 non-null    object
#  9   modifier              567 non-null    object
#  10  author                567 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 48.9+ KB

# %%
homework.isna().sum()
# Out:
# id                      0
# classId                 0
# userId                  0
# label                   2
# date                    0
# type                    0
# nbRequestUsers          0
# creationDate            0
# lastModificationDate    0
# modifier                0
# author                  0
# dtype: int64

# %%
homework.nbRequestUsers.unique()
# Out:
# array([0, 1, 2])

# %%
homework.where(homework!="Null")
# Out:
#                            id                   classId  \
# 0    5f4914744ded6f0001f02c9e  5f4914554ded6f0001f02c8c
# 1    5f4914b64ded6f0001f02ce9  5f49139a4ded6f0001f02a08
# 2    5f4915a24ded6f0001f02e3d  5f4914934ded6f0001f02cb4
# 3    5f72076dfb6eb600013dda15  5f4e27ab2447780001556cf0
# 4    5f665d52046ca50001ad3403  5f665d10046ca50001ad33f2
# ..                        ...                       ...
# 562  605aa0a974ec0b012da9d060  6058fe53e51bcc5e8691532b
# 563  605aa0a974ec0b012da9d062  6059363be51bcc5e86915385
# 564  605aa0a974ec0b012da9d064  605a2cdbe51bcc5e8691544a
# 565  605aa0a974ec0b012da9d066  605a2cdbe51bcc5e8691544a
# 566  605aa0a974ec0b012da9d068  605a367db787e274216edaaf
#
#                        userId  \
# 0    5f4910754ded6f0001f026a7
# 1    5ec23afd7b059100010baa8b
# 2    5f4911ef4ded6f0001f0271d
# 3    5e5ccf59026b4800016b27b0
# 4    5f665c26fb6eb600010f65eb
# ..                        ...
# 562  5fbfaacc79aa5d00018e8236
# 563  5fbfaacc79aa5d00018e8236
# ...

# %% [markdown]
# ## Notifications

# %%
notification = pd.read_csv("data/exportNotification-Grid view.csv")
print(notification.shape)
notification
# Out:
# (4299, 15)
#                             id                    userId parentId  \
# 0     5ea70180c6cc020001891469  5e617d019fed0e00015600a9     Null
# 1     5e621c689fed0e0001560199  5e6212b29fed0e00015600be     Null
# 2     5ea70180c6cc020001891473  5e6212b29fed0e00015600be     Null
# 3     5e839b129fed0e0001f16502  5e62341f9fed0e0001560209     Null
# 4     5e6223409fed0e00015601da  5e617dbb9fed0e00015600b1     Null
# ...                        ...                       ...      ...
# 4294  602bdb561c2e36512e0aafdf  602bdb561c2e36512e0aafdc     Null
# 4295  605934cfb787e274216ed995  605934cfb787e274216ed994     Null
# 4296  605934cfb787e274216ed996  605934cfb787e274216ed994     Null
# 4297  605934cfb787e274216ed997  605934cfb787e274216ed994     Null
# 4298  6059363ce51bcc5e86915388  605934cfb787e274216ed994     Null
#
#                        eventId homeworkRequestId classId documentId  \
# 0     5ea70180c6cc020001891466              Null    Null       Null
# ...

# %%
notification.sphere.unique()
# Out:
# array(['EVENT', nan, 'HOME', 'SCHOOL'], dtype=object)

# %%
notification.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4299 entries, 0 to 4298
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    4299 non-null   object
#  1   userId                4299 non-null   object
#  2   parentId              4299 non-null   object
#  3   eventId               4299 non-null   object
#  4   homeworkRequestId     4299 non-null   object
#  5   classId               4299 non-null   object
#  6   documentId            4299 non-null   object
#  7   message               4289 non-null   object
#  8   priority              4299 non-null   int64
#  9   creationDate          4299 non-null   object
#  10  lastModificationDate  4299 non-null   object
#  11  expirationDate        4299 non-null   object
#  12  notificationType      4299 non-null   object
#  13  sphere                4290 non-null   object
#  14  title                 3130 non-null   object
# ...

# %%
notification[~(notification["classId"]=="Null")]
# Out:
#                             id                    userId parentId eventId  \
# 472   5f68ba8afb6eb600010f68c1  5e5e2cb73dc85e0001e90672     Null    Null
# 473   5f68c1a0046ca50001ad371c  5e5ccf59026b4800016b27b0     Null    Null
# 474   5f68ba8afb6eb600010f68c4  5f1099c1287d3e0001cc75b9     Null    Null
# 475   5f68ba8afb6eb600010f68c2  5f64de18722f7500016ed76b     Null    Null
# 478   5f68c1da046ca50001ad372c  5e5ccf59026b4800016b27b0     Null    Null
# ...                        ...                       ...      ...     ...
# 4238  605458619a62d40d7ad1228f  60511b429a62d40d7ad11624     Null    Null
# 4239  605458619a62d40d7ad12291  60511b429a62d40d7ad11624     Null    Null
# 4252  6058be4be51bcc5e869151f4  60522fe49a62d40d7ad118b0     Null    Null
# 4253  6058be4be51bcc5e869151f6  605236719a62d40d7ad11977     Null    Null
# 4255  6058c1b8e51bcc5e86915230  605226efa0bad44c9a6c9b54     Null    Null
#
#              homeworkRequestId                   classId  \
# ...

# %%
notification.message.unique()
# Out:
# array(['Vous Ãªtes invité Ã\xa0 lévénement {0} organisé par {1}',
#        "Vous êtes invité à L'événement c'est le week-end ! organisé par [Samuel Rémy]",
#        "Vous êtes invité à L'événement a la maison  organisé par [Jérémie Lachcar]",
#        "Vous êtes invité à L'événement Repas chez laura  organisé par [Laura Michael]",
#        "Vous êtes invité à L'événement 1 er test caro organisé par [Caroline Guérard]",
#        "Vous êtes invité à L'événement Les lyonnais à Paris organisé par [Marie Lewin]",
#        'You are invited to the event Réunion feamzy organized by [Marie Lewin]',
#        'You are invited to the event break en normandie organized by [Simon Guerard]',
#        "L'événement a été modifié",
#        "Vous êtes invité à L'événement Un petit télé apéro ?  organisé par [Marie Lewin]",
#        "Vous êtes invité à L'événement hello test organisé par [Jérémie Lachcar]",
#        'You are invited to the event Côte de boeuf party organized by [Marie Lewin]',
# ...

# %%
notification.message = notification.message.str.replace("Ãª","ê")
notification.message = notification.message.str.replace("Ã","à")
notification.message = notification.message.replace("lévénement","l'événement")
notification.message = notification.message.replace("L'événement","l'événement")
notification.message = notification.message.replace("  lévénement ","à l'événement")
notification.message
# Out:
# 0       Vous êtes invité à  lévénement {0} organisé pa...
# 1       Vous êtes invité à L'événement c'est le week-e...
# 2       Vous êtes invité à  lévénement {0} organisé pa...
# 3       Vous êtes invité à L'événement a la maison  or...
# 4       Vous êtes invité à L'événement Repas chez laur...
#                               ...
# 4294                     Trouvez la classe de vos enfants
# 4295                            Pour voir tous les events
# 4296        Partagez les devoirs et l'agenda de la classe
# 4297                     Trouvez la classe de vos enfants
# 4298                          Hello, Welcome in class 6D.
# Name: message, Length: 4299, dtype: object

# %%
print(notification.message[0])
# Out:
# Vous êtes invité à  lévénement {0} organisé par {1}

# %%
notification.message.str.encode('latin1')
# Out:
# 0       b'Vous \xc3\xaates invit\xe9 \xc3\xa0 l\xe9v\x...
# 1       b"Vous \xeates invit\xe9 \xe0 L'\xe9v\xe9nemen...
# 2       b'Vous \xc3\xaates invit\xe9 \xc3\xa0 l\xe9v\x...
# 3       b"Vous \xeates invit\xe9 \xe0 L'\xe9v\xe9nemen...
# 4       b"Vous \xeates invit\xe9 \xe0 L'\xe9v\xe9nemen...
#                               ...
# 4294                  b'Trouvez la classe de vos enfants'
# 4295                         b'Pour voir tous les events'
# 4296     b"Partagez les devoirs et l'agenda de la classe"
# 4297                  b'Trouvez la classe de vos enfants'
# 4298                       b'Hello, Welcome in class 6D.'
# Name: message, Length: 4299, dtype: object

# %% [markdown]
# ## Conclusions

# %% [markdown]
# **Tables structures**
# - Users: 2928 rows x 12 columns
# - Classes: 313 rows x 28 columns
# - Homeworks: 567 rows x 11 columns
# - Events: 2426 rows x 22 columns
# - Notifications: 4299 rows x 15 columns
# - Documents: 51 rows x 13 columns
#
#
# **Null values:** Lot's of columns with null values. Some are NaN identified by python and in the `Notifications` table, the values are indicated as a tring "Null".
# - To be careful with:
